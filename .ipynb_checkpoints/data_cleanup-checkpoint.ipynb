# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np

# %%
houses_df = pd.read_csv('data/train.csv')

# %% [markdown]
# ## Missing

# %%
missing_cols_count = houses_df.isna().sum(0).sort_values(ascending=False)
print(missing_cols_count[missing_cols_count>0])
print("total number of observations: ", len(houses_df))
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64
# total number of observations 1460

# %%
houses_df.T[(houses_df.isna().sum(0) > 1)].T
# Out:
#      LotFrontage Alley MasVnrType MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 0             65   NaN    BrkFace        196       Gd       TA           No
# 1             80   NaN       None          0       Gd       TA           Gd
# 2             68   NaN    BrkFace        162       Gd       TA           Mn
# 3             60   NaN       None          0       TA       Gd           No
# 4             84   NaN    BrkFace        350       Gd       TA           Av
# 5             85   NaN       None          0       Gd       TA           No
# 6             75   NaN      Stone        186       Ex       TA           Av
# 7            NaN   NaN      Stone        240       Gd       TA           Mn
# 8             51   NaN       None          0       TA       TA           No
# 9             50   NaN       None          0       TA       TA           No
# 10            70   NaN       None          0       TA       TA           No
# 11            85   NaN      Stone        286       Ex       TA           No
# 12           NaN   NaN       None          0       TA       TA           No
# 13            91   NaN      Stone        306       Gd       TA           Av
# 14           NaN   NaN    BrkFace        212       TA       TA           No
# 15            51   NaN       None          0       TA       TA           No
# 16           NaN   NaN    BrkFace        180       TA       TA           No
# 17            72   NaN       None          0      NaN      NaN          NaN
# 18            66   NaN       None          0       TA       TA           No
# 19            70   NaN       None          0       TA       TA           No
# 20           101   NaN    BrkFace        380       Ex       TA           Av
# 21            57  Grvl       None          0       TA       TA           No
# 22            75   NaN    BrkFace        281       Gd       TA           No
# 23            44   NaN       None          0       Gd       TA           No
# 24           NaN   NaN       None          0       TA       TA           Mn
# 25           110   NaN      Stone        640       Gd       TA           No
# 26            60   NaN       None          0       TA       TA           Mn
# 27            98   NaN      Stone        200       Ex       TA           No
# 28            47   NaN       None          0       TA       TA           Gd
# 29            60   NaN       None          0       TA       TA           No
# ...          ...   ...        ...        ...      ...      ...          ...
# 1430          60   NaN       None          0       Gd       Gd           Av
# 1431         NaN   NaN       None          0       Gd       TA           No
# 1432          60  Grvl       None          0       TA       TA           No
# 1433          93   NaN    BrkFace        318       Gd       TA           No
# 1434          80   NaN       None          0       TA       TA           No
# 1435          80   NaN    BrkFace        237       TA       TA           No
# 1436          60   NaN       None          0       TA       TA           No
# 1437          96   NaN      Stone        426       Ex       TA           Av
# 1438          90   NaN       None          0       TA       TA           No
# 1439          80   NaN    BrkFace         96       TA       TA           No
# 1440          79   NaN       None          0       Ex       TA           No
# 1441         NaN   NaN    BrkFace        147       Gd       TA           Av
# 1442          85   NaN      Stone        160       Ex       TA           Av
# 1443         NaN   NaN       None          0       TA       TA           No
# 1444          63   NaN    BrkFace        106       Gd       TA           Av
# 1445          70   NaN       None          0       TA       TA           Gd
# 1446         NaN   NaN    BrkFace        189       TA       TA           No
# 1447          80   NaN    BrkFace        438       Gd       TA           No
# 1448          70   NaN       None          0       Fa       TA           No
# 1449          21   NaN       None          0       Gd       TA           Av
# 1450          60   NaN       None          0       Gd       TA           No
# 1451          78   NaN      Stone        194       Gd       TA           No
# 1452          35   NaN    BrkFace         80       Gd       TA           Gd
# 1453          90   NaN       None          0       Gd       TA           No
# 1454          62  Pave       None          0       Gd       TA           No
# 1455          62   NaN       None          0       Gd       TA           No
# 1456          85   NaN      Stone        119       Gd       TA           No
# 1457          66   NaN       None          0       TA       Gd           No
# 1458          68   NaN       None          0       TA       TA           Mn
# 1459          75   NaN       None          0       TA       TA           No
#
#      BsmtFinType1 BsmtFinType2 FireplaceQu GarageType GarageYrBlt  \
# 0             GLQ          Unf         NaN     Attchd        2003
# 1             ALQ          Unf          TA     Attchd        1976
# 2             GLQ          Unf          TA     Attchd        2001
# 3             ALQ          Unf          Gd     Detchd        1998
# 4             GLQ          Unf          TA     Attchd        2000
# 5             GLQ          Unf         NaN     Attchd        1993
# 6             GLQ          Unf          Gd     Attchd        2004
# 7             ALQ          BLQ          TA     Attchd        1973
# 8             Unf          Unf          TA     Detchd        1931
# 9             GLQ          Unf          TA     Attchd        1939
# 10            Rec          Unf         NaN     Detchd        1965
# 11            GLQ          Unf          Gd    BuiltIn        2005
# 12            ALQ          Unf         NaN     Detchd        1962
# 13            Unf          Unf          Gd     Attchd        2006
# 14            BLQ          Unf          Fa     Attchd        1960
# 15            Unf          Unf         NaN     Detchd        1991
# 16            ALQ          Unf          TA     Attchd        1970
# 17            NaN          NaN         NaN    CarPort        1967
# 18            GLQ          Unf         NaN     Detchd        2004
# 19            LwQ          Unf         NaN     Attchd        1958
# 20            Unf          Unf          Gd    BuiltIn        2005
# 21            Unf          Unf          Gd     Attchd        1930
# 22            Unf          Unf          Gd     Attchd        2002
# 23            GLQ          Unf          TA     Attchd        1976
# 24            Rec          ALQ          TA     Attchd        1968
# 25            Unf          Unf          Gd     Attchd        2007
# 26            BLQ          Rec         NaN     Detchd        2005
# 27            GLQ          Unf          Gd     Attchd        2008
# 28            BLQ          Unf          Gd     Attchd        1957
# 29            Unf          Unf         NaN     Detchd        1920
# ...           ...          ...         ...        ...         ...
# 1430          Unf          Unf          Gd    BuiltIn        2005
# 1431          LwQ          Unf         NaN     Attchd        1976
# 1432          Unf          Unf         NaN     Detchd        1928
# 1433          Unf          Unf          TA     Attchd        2000
# 1434          ALQ          Unf          Gd     Attchd        1977
# 1435          Unf          Unf          Gd     Attchd        1962
# 1436          ALQ          Unf         NaN     Detchd        1974
# 1437          GLQ          Unf          Gd     Attchd        2008
# 1438          GLQ          Unf         NaN     Attchd        1957
# 1439          GLQ          Rec          TA     Attchd        1979
# 1440          Unf          Unf          Gd     Detchd        1993
# 1441          GLQ          Unf          TA     Attchd        2004
# 1442          GLQ          Unf          Ex     Attchd        2008
# 1443          Unf          Unf          Gd     Detchd        1916
# 1444          Unf          Unf         NaN     Attchd        2004
# 1445          LwQ          Rec         NaN     Detchd        1990
# 1446          Rec          Unf         NaN     Attchd        1962
# 1447          GLQ          Unf          TA     Attchd        1995
# 1448          Unf          Unf         NaN     Detchd        1950
# 1449          GLQ          Unf         NaN        NaN         NaN
# 1450          Unf          Unf         NaN        NaN         NaN
# 1451          Unf          Unf          Gd     Attchd        2008
# 1452          GLQ          Unf         NaN    Basment        2005
# 1453          Unf          Unf         NaN        NaN         NaN
# 1454          GLQ          Unf         NaN     Attchd        2004
# 1455          Unf          Unf          TA     Attchd        1999
# 1456          ALQ          Rec          TA     Attchd        1978
# 1457          GLQ          Unf          Gd     Attchd        1941
# 1458          GLQ          Rec         NaN     Attchd        1950
# 1459          BLQ          LwQ         NaN     Attchd        1965
#
#      GarageFinish GarageQual GarageCond PoolQC  Fence MiscFeature
# 0             RFn         TA         TA    NaN    NaN         NaN
# 1             RFn         TA         TA    NaN    NaN         NaN
# 2             RFn         TA         TA    NaN    NaN         NaN
# 3             Unf         TA         TA    NaN    NaN         NaN
# 4             RFn         TA         TA    NaN    NaN         NaN
# 5             Unf         TA         TA    NaN  MnPrv        Shed
# 6             RFn         TA         TA    NaN    NaN         NaN
# 7             RFn         TA         TA    NaN    NaN        Shed
# 8             Unf         Fa         TA    NaN    NaN         NaN
# 9             RFn         Gd         TA    NaN    NaN         NaN
# 10            Unf         TA         TA    NaN    NaN         NaN
# 11            Fin         TA         TA    NaN    NaN         NaN
# 12            Unf         TA         TA    NaN    NaN         NaN
# 13            RFn         TA         TA    NaN    NaN         NaN
# 14            RFn         TA         TA    NaN   GdWo         NaN
# 15            Unf         TA         TA    NaN  GdPrv         NaN
# 16            Fin         TA         TA    NaN    NaN        Shed
# 17            Unf         TA         TA    NaN    NaN        Shed
# 18            Unf         TA         TA    NaN    NaN         NaN
# 19            Unf         TA         TA    NaN  MnPrv         NaN
# 20            RFn         TA         TA    NaN    NaN         NaN
# 21            Unf         TA         TA    NaN  GdPrv         NaN
# 22            RFn         TA         TA    NaN    NaN         NaN
# 23            Unf         TA         TA    NaN    NaN         NaN
# 24            Unf         TA         TA    NaN  MnPrv         NaN
# 25            RFn         TA         TA    NaN    NaN         NaN
# 26            Unf         TA         TA    NaN    NaN         NaN
# 27            RFn         TA         TA    NaN    NaN         NaN
# 28            RFn         TA         TA    NaN    NaN         NaN
# 29            Unf         Fa         TA    NaN    NaN         NaN
# ...           ...        ...        ...    ...    ...         ...
# 1430          Fin         TA         TA    NaN    NaN         NaN
# 1431          RFn         TA         TA    NaN    NaN         NaN
# 1432          Unf         Fa         Fa    NaN    NaN         NaN
# 1433          Fin         TA         TA    NaN    NaN         NaN
# 1434          RFn         TA         TA    NaN    NaN         NaN
# 1435          RFn         TA         TA    NaN  GdPrv         NaN
# 1436          Unf         TA         TA    NaN   GdWo         NaN
# 1437          Fin         TA         TA    NaN    NaN         NaN
# 1438          Unf         TA         TA    NaN  MnPrv         NaN
# 1439          RFn         TA         TA    NaN    NaN         NaN
# 1440          Fin         TA         TA    NaN    NaN         NaN
# 1441          RFn         TA         TA    NaN    NaN         NaN
# 1442          Fin         TA         TA    NaN    NaN         NaN
# 1443          Unf         Fa         Po    NaN    NaN         NaN
# 1444          RFn         TA         TA    NaN    NaN         NaN
# 1445          Unf         TA         TA    NaN    NaN         NaN
# 1446          Unf         TA         TA    NaN    NaN         NaN
# 1447          RFn         TA         TA    NaN    NaN         NaN
# 1448          Unf         Fa         TA    NaN   GdWo         NaN
# 1449          NaN        NaN        NaN    NaN    NaN         NaN
# 1450          NaN        NaN        NaN    NaN    NaN         NaN
# 1451          Fin         TA         TA    NaN    NaN         NaN
# 1452          Fin         TA         TA    NaN    NaN         NaN
# 1453          NaN        NaN        NaN    NaN    NaN         NaN
# 1454          RFn         TA         TA    NaN    NaN         NaN
# 1455          RFn         TA         TA    NaN    NaN         NaN
# 1456          Unf         TA         TA    NaN  MnPrv         NaN
# 1457          RFn         TA         TA    NaN  GdPrv        Shed
# 1458          Unf         TA         TA    NaN    NaN         NaN
# 1459          Fin         TA         TA    NaN    NaN         NaN
#
# [1460 rows x 18 columns]
